# %%
import pandas as pd

# %%
df=pd.read_csv('time_series.csv')

# %%
df.head()
# Out:
#          date      AAPL     MSFT
# 0  2015-01-02  101.9635  42.5999
# 1  2015-01-05   99.0910  42.2036
# 2  2015-01-06   99.1003  41.5886
# 3  2015-01-07  100.4899  42.1170
# 4  2015-01-08  104.3510  43.3560

# %%
# Out:
#             date      AAPL      MSFT
# 0     2015-01-02  101.9635   42.5999
# 1     2015-01-05   99.0910   42.2036
# 2     2015-01-06   99.1003   41.5886
# 3     2015-01-07  100.4899   42.1170
# 4     2015-01-08  104.3510   43.3560
# ...          ...       ...       ...
# 1001  2018-12-24  146.8300   94.1300
# 1002  2018-12-26  157.1700  100.5600
# 1003  2018-12-27  156.1500  101.1800
# 1004  2018-12-28  156.2300  100.3900
# 1005  2018-12-31  157.7400  101.5700
#
# [1006 rows x 3 columns]
